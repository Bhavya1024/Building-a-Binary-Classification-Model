# %%
def dataset3():
    
    import pandas as pd
    import numpy as np
    from sklearn.metrics import accuracy_score
    import tensorflow as tf
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Attention
    from tensorflow.keras import layers
    
    # read text sequence dataset
    train_seq_df = pd.read_csv("datasets/train/train_text_seq.csv")
    train_seq_X = train_seq_df['input_str'].tolist()
    train_seq_Y = train_seq_df['label'].tolist()
       
    test_seq_X = pd.read_csv("datasets/test/test_text_seq.csv")['input_str'].tolist()

    # Each input which is a string of 50 digits is coverted into numpy integer array of 50 digits([1 2 0 4 2...])
    X_train= np.array([list(map(int,train_seq_X[i])) for i in range(7080)])
    y_train=np.array(train_seq_Y)
    X_test=np.array([list(map(int,test_seq_X[i])) for i in range(len(test_seq_X))])

    # LSTMs are well-suited for sequence data like time series or text, but here we can treat each sample's 50 features as a sequence. 
    # We’ll design an LSTM network and apply it to the dataset.
    # Model definition
    model = Sequential()
    
    #1. Add an Embedding layer 
        
    embedding_dim = 32
    model.add(Embedding(input_dim=13, output_dim=embedding_dim, input_length=50))
    
    # 2. LSTM layer with 30 units
    model.add(LSTM(32))
    
    # 3. Dropout layer to prevent overfitting (0.5 dropout)
    model.add(Dropout(0.5))
    
    # 4. Batch Normalization layer for stable learning
    model.add(BatchNormalization())
    
    # 5. Dense layer with 15 units (ReLU activation)
    model.add(Dense(15, activation='relu'))
    
    # 6. Another Dropout layer to further regularize
    model.add(Dropout(0.5))
    
    # 7. Dense layer with 15 units (ReLU activation)
    model.add(Dense(15, activation='relu'))
    
    # 8. Final output layer for binary classification (1 unit, sigmoid activation)
    model.add(Dense(1, activation='sigmoid'))
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.004), 
                  loss='binary_crossentropy', 
                  metrics=['accuracy'])
    
    # Train the model 
    model.fit(X_train, y_train, epochs=200, batch_size=32,verbose=1)
    
    # Make predictions on the test set
    predictions = model.predict(X_test)
    
    # Convert predictions to binary labels (0 or 1)
    predicted_labels = (predictions > 0.5).astype(int).reshape(-1)
    
    # Store the predictions in a text file with the column name "test label"
    with open("pred_textseq.txt", "w") as file:
        file.write("test label\n")  # Column header
        for label in predicted_labels:
            file.write(f"{label}\n")

# %%
dataset3()
# Out:
# Epoch 1/75
# C:\Users\puspe\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.5005 - loss: 0.7041
# Epoch 2/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.5204 - loss: 0.6867
# Epoch 3/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.5854 - loss: 0.6740
# Epoch 4/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6036 - loss: 0.6609
# Epoch 5/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6165 - loss: 0.6570
# Epoch 6/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6470 - loss: 0.6412
# Epoch 7/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6410 - loss: 0.6426
# Epoch 8/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6515 - loss: 0.6301
# Epoch 9/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6599 - loss: 0.6220
# Epoch 10/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6413 - loss: 0.6372
# Epoch 11/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6757 - loss: 0.6128
# Epoch 12/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6829 - loss: 0.5984
# Epoch 13/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6989 - loss: 0.5899
# Epoch 14/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6892 - loss: 0.5823
# Epoch 15/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7047 - loss: 0.5611
# Epoch 16/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7164 - loss: 0.5434
# Epoch 17/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7366 - loss: 0.5179
# Epoch 18/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7556 - loss: 0.5072
# Epoch 19/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7601 - loss: 0.4942
# Epoch 20/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7950 - loss: 0.4490
# Epoch 21/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7843 - loss: 0.4496
# Epoch 22/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8083 - loss: 0.4250
# Epoch 23/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8224 - loss: 0.3984
# Epoch 24/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8242 - loss: 0.3925
# Epoch 25/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8335 - loss: 0.3746
# Epoch 26/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8437 - loss: 0.3551
# Epoch 27/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8479 - loss: 0.3614
# Epoch 28/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8657 - loss: 0.3233
# Epoch 29/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8670 - loss: 0.3145
# Epoch 30/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8617 - loss: 0.3312
# Epoch 31/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8808 - loss: 0.2874
# Epoch 32/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8850 - loss: 0.2900
# Epoch 33/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8864 - loss: 0.2869
# Epoch 34/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8886 - loss: 0.2667
# Epoch 35/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8989 - loss: 0.2488
# Epoch 36/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8922 - loss: 0.2679
# Epoch 37/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9075 - loss: 0.2314
# Epoch 38/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9047 - loss: 0.2348
# Epoch 39/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8950 - loss: 0.2675
# Epoch 40/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9073 - loss: 0.2274
# Epoch 41/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9070 - loss: 0.2290
# Epoch 42/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9052 - loss: 0.2301
# Epoch 43/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9167 - loss: 0.2175
# Epoch 44/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9144 - loss: 0.2081
# Epoch 45/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9119 - loss: 0.2232
# Epoch 46/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9062 - loss: 0.2243
# Epoch 47/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9191 - loss: 0.2080
# Epoch 48/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9325 - loss: 0.1854
# Epoch 49/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9217 - loss: 0.1992
# Epoch 50/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9208 - loss: 0.1901
# Epoch 51/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9220 - loss: 0.1954
# Epoch 52/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9179 - loss: 0.2119
# Epoch 53/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9380 - loss: 0.1612
# Epoch 54/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9350 - loss: 0.1721
# Epoch 55/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9326 - loss: 0.1670
# Epoch 56/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9404 - loss: 0.1669
# Epoch 57/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9379 - loss: 0.1694
# Epoch 58/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9400 - loss: 0.1586
# Epoch 59/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9447 - loss: 0.1441
# Epoch 60/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9324 - loss: 0.1805
# Epoch 61/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9338 - loss: 0.1712
# Epoch 62/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9416 - loss: 0.1424
# Epoch 63/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9436 - loss: 0.1453
# Epoch 64/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9455 - loss: 0.1386
# Epoch 65/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9445 - loss: 0.1509
# Epoch 66/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9374 - loss: 0.1677
# Epoch 67/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9509 - loss: 0.1264
# Epoch 68/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9421 - loss: 0.1457
# Epoch 69/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9407 - loss: 0.1559
# Epoch 70/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9338 - loss: 0.1658
# Epoch 71/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9513 - loss: 0.1334
# Epoch 72/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9388 - loss: 0.1680
# Epoch 73/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9466 - loss: 0.1518
# Epoch 74/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9490 - loss: 0.1315
# Epoch 75/75
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9489 - loss: 0.1334
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataset3()
#
# Cell In[1], line 75, in dataset3()
#      72         file.write(f"{label}\n")
#      74 # Model Summary
# ---> 75 if percent==1:
#      76     model.summary()
#      77 return accuracy
#
# NameError: name 'percent' is not defined
